# %% [markdown]
# # 基于Tensorflow实现word2vec

# %% [markdown]
# ## 流程
#
# 1. 数据：可以是一篇文章或多篇文章，词与词之间要有逻辑关系。
# 2. 数据处理：词转换成索引。
# 3. 数据清洗：按照词频，忽略出现次数少的。
# 4. batch：输入什么？输出什么？也是这个任务中的重点。
# 5. model：CBOW，skip-gram，这里选用skip-gram。输入一个词，输出上下文。

# %% [markdown]
# ## 导入工具包

# %%
import collections
import os
import random
import urllib
import zipfile
import datetime
import numpy as np
import tensorflow as tf

# %% [markdown]
# ## 设置参数

# %%
# 训练参数
learning_rate = 0.1
batch_size = 128
num_steps = 3000000 # 训练次数
display_step = 10000 # 多少次显示损失值
eval_step = 200000 # 多少次验证一下

# 测试样例，用来进行验证
eval_words = ['nine', 'of', 'going', 'hardware', 'american', 'britain']

# Word2Vec 参数
embedding_size = 200 # 词向量维度
max_vocabulary_size = 50000 # 语料库大小，不重复的词的个数
min_occurrence = 10 # 最小词频
skip_window = 3 # 左右窗口大小
num_skips = 2 # 一次制作多少个输入输出对
num_sampled = 64 # 负采样

# %% [markdown]
# ## 加载数据

# %%
# 加载训练数据，其实什么数据都行
data_path = 'text8.zip'
with zipfile.ZipFile(data_path) as f:
    text_words = f.read(f.namelist()[0]).lower().split()

# %%
# 看一下单词个数
len(text_words)
# Out:
# 17005207

# %% [markdown]
# ## 创建一个计数器

# %%
# 计算每个词出现了多少次
count = [('UNK', -1)]
# 基于词频返回max_vocabulary_size个常用词
count.extend(collections.Counter(text_words).most_common(max_vocabulary_size - 1))

# %%
# 打印一下，看看前10个
count[0:10]
# Out:
# [('UNK', -1),
#  (b'the', 1061396),
#  (b'of', 593677),
#  (b'and', 416629),
#  (b'one', 411764),
#  (b'in', 372201),
#  (b'a', 325873),
#  (b'to', 316376),
#  (b'zero', 264975),
#  (b'nine', 250430)]

# %% [markdown]
# - 默认已经是排序好了的

# %% [markdown]
# - 别忘了，咱们还设置了min_occurrence参数，需要判断每一个词是否满足给定条件

# %% [markdown]
# ## 清除词频过低的单词

# %%
# 剔除掉出现次数少于'min_occurrence'的词
for i in range(len(count) - 1, -1, -1): # 从start到end每次step多少
    if count[i][1] < min_occurrence:
        count.pop(i)
    else:
        # 判断时，从小到大排序的，所以跳出时候剩下的都是满足条件的
        break

# %% [markdown]
# ## 词-ID映射

# %%
# 计算语料库大小
vocabulary_size = len(count)
# 每个词都分配一个ID，字典结构
word2id = dict()
for i, (word, _)in enumerate(count):
    word2id[word] = i

# %%
word2id
# Out:
# {'UNK': 0,
#  b'the': 1,
#  b'of': 2,
#  b'and': 3,
#  b'one': 4,
#  b'in': 5,
#  b'a': 6,
#  b'to': 7,
#  b'zero': 8,
#  b'nine': 9,
#  b'two': 10,
#  b'is': 11,
#  b'as': 12,
#  b'eight': 13,
#  b'for': 14,
#  b's': 15,
#  b'five': 16,
#  b'three': 17,
#  b'was': 18,
#  b'by': 19,
#  b'that': 20,
#  b'four': 21,
#  b'six': 22,
#  b'seven': 23,
#  b'with': 24,
#  b'on': 25,
#  b'are': 26,
#  b'it': 27,
#  b'from': 28,
#  b'or': 29,
#  b'his': 30,
#  b'an': 31,
#  b'be': 32,
#  b'this': 33,
#  b'which': 34,
#  b'at': 35,
#  b'he': 36,
#  b'also': 37,
#  b'not': 38,
#  b'have': 39,
#  b'were': 40,
#  b'has': 41,
#  b'but': 42,
#  b'other': 43,
#  b'their': 44,
#  b'its': 45,
#  b'first': 46,
#  b'they': 47,
#  b'some': 48,
#  b'had': 49,
#  b'all': 50,
#  b'more': 51,
#  b'most': 52,
#  b'can': 53,
#  b'been': 54,
#  b'such': 55,
#  b'many': 56,
#  b'who': 57,
#  b'new': 58,
#  b'used': 59,
#  b'there': 60,
#  b'after': 61,
#  b'when': 62,
#  b'into': 63,
#  b'american': 64,
#  b'time': 65,
#  b'these': 66,
#  b'only': 67,
#  b'see': 68,
#  b'may': 69,
#  b'than': 70,
#  b'world': 71,
#  b'i': 72,
#  b'b': 73,
#  b'would': 74,
#  b'd': 75,
#  b'no': 76,
#  b'however': 77,
#  b'between': 78,
#  b'about': 79,
#  b'over': 80,
#  b'years': 81,
#  b'states': 82,
#  b'people': 83,
#  b'war': 84,
#  b'during': 85,
#  b'united': 86,
#  b'known': 87,
#  b'if': 88,
#  b'called': 89,
#  b'use': 90,
#  b'th': 91,
#  b'system': 92,
#  b'often': 93,
#  b'state': 94,
#  b'so': 95,
#  b'history': 96,
#  b'will': 97,
#  b'up': 98,
#  b'while': 99,
#  b'where': 100,
#  b'city': 101,
#  b'being': 102,
#  b'english': 103,
#  b'then': 104,
#  b'any': 105,
#  b'both': 106,
#  b'under': 107,
#  b'out': 108,
#  b'made': 109,
#  b'well': 110,
#  b'her': 111,
#  b'e': 112,
#  b'number': 113,
#  b'government': 114,
#  b'them': 115,
#  b'm': 116,
#  b'later': 117,
#  b'since': 118,
#  b'him': 119,
#  b'part': 120,
#  b'name': 121,
#  b'c': 122,
#  b'century': 123,
#  b'through': 124,
#  b'because': 125,
#  b'x': 126,
#  b'university': 127,
#  b'early': 128,
#  b'life': 129,
#  b'british': 130,
#  b'year': 131,
#  b'like': 132,
#  b'same': 133,
#  b'including': 134,
#  b'became': 135,
#  b'example': 136,
#  b'day': 137,
#  b'each': 138,
#  b'even': 139,
#  b'work': 140,
#  b'language': 141,
#  b'although': 142,
#  b'several': 143,
#  b'form': 144,
#  b'john': 145,
#  b'u': 146,
#  b'national': 147,
#  b'very': 148,
#  b'much': 149,
#  b'g': 150,
#  b'french': 151,
#  b'before': 152,
#  b'general': 153,
#  b'what': 154,
#  b't': 155,
#  b'against': 156,
#  b'n': 157,
#  b'high': 158,
#  b'links': 159,
#  b'could': 160,
#  b'based': 161,
#  b'those': 162,
#  b'now': 163,
#  b'second': 164,
#  b'de': 165,
#  b'music': 166,
#  b'another': 167,
#  b'large': 168,
#  b'she': 169,
#  b'f': 170,
#  b'external': 171,
#  b'german': 172,
#  b'different': 173,
#  b'modern': 174,
#  b'great': 175,
#  b'do': 176,
#  b'common': 177,
#  b'set': 178,
#  b'list': 179,
#  b'south': 180,
#  b'series': 181,
#  b'major': 182,
#  b'game': 183,
#  b'power': 184,
#  b'long': 185,
#  b'country': 186,
#  b'king': 187,
#  b'law': 188,
#  b'group': 189,
#  b'film': 190,
#  b'still': 191,
#  b'until': 192,
#  b'north': 193,
#  b'international': 194,
#  b'term': 195,
#  b'we': 196,
#  b'end': 197,
#  b'book': 198,
#  b'found': 199,
#  b'own': 200,
#  b'political': 201,
#  b'party': 202,
#  b'order': 203,
#  b'usually': 204,
#  b'president': 205,
#  b'church': 206,
#  b'you': 207,
#  b'death': 208,
#  b'theory': 209,
#  b'area': 210,
#  b'around': 211,
#  b'include': 212,
#  b'god': 213,
#  b'ii': 214,
#  b'way': 215,
#  b'did': 216,
#  b'military': 217,
#  b'population': 218,
#  b'using': 219,
#  b'though': 220,
#  b'small': 221,
#  b'following': 222,
#  b'within': 223,
#  b'non': 224,
#  b'human': 225,
#  b'left': 226,
#  b'main': 227,
#  b'among': 228,
#  b'point': 229,
#  b'r': 230,
#  b'due': 231,
#  b'p': 232,
#  b'considered': 233,
#  b'public': 234,
#  b'popular': 235,
#  b'computer': 236,
#  b'west': 237,
#  b'family': 238,
#  b'east': 239,
#  b'information': 240,
#  b'important': 241,
#  b'european': 242,
#  b'man': 243,
#  b'sometimes': 244,
#  b'right': 245,
#  b'old': 246,
#  b'free': 247,
#  b'word': 248,
#  b'without': 249,
#  b'last': 250,
#  b'us': 251,
#  b'members': 252,
#  b'given': 253,
#  b'times': 254,
#  b'roman': 255,
#  b'make': 256,
#  b'h': 257,
#  b'age': 258,
#  b'place': 259,
#  b'l': 260,
#  b'thus': 261,
#  b'science': 262,
#  b'case': 263,
#  b'become': 264,
#  b'systems': 265,
#  b'union': 266,
#  b'born': 267,
#  b'york': 268,
#  b'line': 269,
#  b'countries': 270,
#  b'does': 271,
#  b'isbn': 272,
#  b'st': 273,
#  b'control': 274,
#  b'various': 275,
#  b'others': 276,
#  b'house': 277,
#  b'article': 278,
#  b'island': 279,
#  b'should': 280,
#  b'led': 281,
#  b'back': 282,
#  b'period': 283,
#  b'player': 284,
#  b'europe': 285,
#  b'languages': 286,
#  b'central': 287,
#  b'water': 288,
#  b'few': 289,
#  b'western': 290,
#  b'home': 291,
#  b'began': 292,
#  b'generally': 293,
#  b'less': 294,
#  b'k': 295,
#  b'similar': 296,
#  b'written': 297,
#  b'original': 298,
#  b'best': 299,
#  b'must': 300,
#  b'according': 301,
#  b'school': 302,
#  b'france': 303,
#  b'air': 304,
#  b'single': 305,
#  b'force': 306,
#  b'v': 307,
#  b'land': 308,
#  b'groups': 309,
#  b'down': 310,
#  b'how': 311,
#  b'works': 312,
#  b'development': 313,
#  b'official': 314,
#  b'support': 315,
#  b'england': 316,
#  b'j': 317,
#  b'rather': 318,
#  b'data': 319,
#  b'space': 320,
#  b'greek': 321,
#  b'km': 322,
#  b'named': 323,
#  b'germany': 324,
#  b'just': 325,
#  b'games': 326,
#  b'said': 327,
#  b'version': 328,
#  b'late': 329,
#  b'earth': 330,
#  b'company': 331,
#  b'every': 332,
#  b'economic': 333,
#  b'short': 334,
#  b'published': 335,
#  b'black': 336,
#  b'army': 337,
#  b'off': 338,
#  b'london': 339,
#  b'million': 340,
#  b'body': 341,
#  b'field': 342,
#  b'christian': 343,
#  b'either': 344,
#  b'social': 345,
#  b'empire': 346,
#  b'o': 347,
#  b'developed': 348,
#  b'standard': 349,
#  b'court': 350,
#  b'service': 351,
#  b'kingdom': 352,
#  b'along': 353,
#  b'college': 354,
#  b'republic': 355,
#  b'sea': 356,
#  b'america': 357,
#  b'today': 358,
#  b'result': 359,
#  b'held': 360,
#  b'team': 361,
#  b'light': 362,
#  b'means': 363,
#  b'never': 364,
#  b'especially': 365,
#  b'third': 366,
#  b'further': 367,
#  b'character': 368,
#  b'forces': 369,
#  b'take': 370,
#  b'men': 371,
#  b'society': 372,
#  b'show': 373,
#  b'open': 374,
#  b'possible': 375,
#  b'fact': 376,
#  b'battle': 377,
#  b'took': 378,
#  b'former': 379,
#  b'books': 380,
#  b'soviet': 381,
#  b'river': 382,
#  b'children': 383,
#  b'having': 384,
#  b'good': 385,
#  b'local': 386,
#  b'current': 387,
#  b'son': 388,
#  b'process': 389,
#  b'natural': 390,
#  b'present': 391,
#  b'himself': 392,
#  b'islands': 393,
#  b'total': 394,
#  b'near': 395,
#  b'white': 396,
#  b'days': 397,
#  b'person': 398,
#  b'itself': 399,
#  b'seen': 400,
#  b'culture': 401,
#  b'little': 402,
#  b'above': 403,
#  b'software': 404,
#  b'largest': 405,
#  b'words': 406,
#  b'upon': 407,
#  b'level': 408,
#  b'father': 409,
#  b'created': 410,
#  b'side': 411,
#  b'red': 412,
#  b'references': 413,
#  b'press': 414,
#  b'full': 415,
#  b'region': 416,
#  b'almost': 417,
#  b'image': 418,
#  b'al': 419,
#  b'famous': 420,
#  b'play': 421,
#  b'came': 422,
#  b'role': 423,
#  b'once': 424,
#  b'certain': 425,
#  b'league': 426,
#  b'jewish': 427,
#  b'james': 428,
#  b'january': 429,
#  b'site': 430,
#  b'again': 431,
#  b'numbers': 432,
#  b'art': 433,
#  b'member': 434,
#  b'areas': 435,
#  b'movement': 436,
#  b'religious': 437,
#  b'type': 438,
#  b'march': 439,
#  b'community': 440,
#  b'story': 441,
#  b'played': 442,
#  b'production': 443,
#  b'released': 444,
#  b'center': 445,
#  b'rights': 446,
#  b'real': 447,
#  b'related': 448,
#  b'foreign': 449,
#  b'low': 450,
#  b'ancient': 451,
#  b'terms': 452,
#  b'view': 453,
#  b'source': 454,
#  b'act': 455,
#  b'minister': 456,
#  b'change': 457,
#  b'energy': 458,
#  b'produced': 459,
#  b'research': 460,
#  b'actor': 461,
#  b'making': 462,
#  b'civil': 463,
#  b'december': 464,
#  b'women': 465,
#  b'special': 466,
#  b'style': 467,
#  b'william': 468,
#  b'design': 469,
#  b'japanese': 470,
#  b'available': 471,
#  b'chinese': 472,
#  b'forms': 473,
#  b'canada': 474,
#  b'northern': 475,
#  b'died': 476,
#  b'class': 477,
#  b'living': 478,
#  b'next': 479,
#  b'particular': 480,
#  b'program': 481,
#  b'council': 482,
#  b'television': 483,
#  b'head': 484,
#  b'david': 485,
#  b'china': 486,
#  b'middle': 487,
#  b'established': 488,
#  b'hand': 489,
#  b'bc': 490,
#  b'far': 491,
#  b'july': 492,
#  b'function': 493,
#  b'position': 494,
#  b'y': 495,
#  b'built': 496,
#  b'george': 497,
#  b'band': 498,
#  b'together': 499,
#  b'w': 500,
#  b'latin': 501,
#  b'thought': 502,
#  b'eastern': 503,
#  b'charles': 504,
#  b'parts': 505,
#  b'instead': 506,
#  b'study': 507,
#  b'might': 508,
#  b'india': 509,
#  b'code': 510,
#  b'included': 511,
#  b'meaning': 512,
#  b'trade': 513,
#  b'per': 514,
#  b'june': 515,
#  b'least': 516,
#  b'half': 517,
#  b'model': 518,
#  b'economy': 519,
#  b'prime': 520,
#  b'traditional': 521,
#  b'always': 522,
#  b'capital': 523,
#  b'range': 524,
#  b'november': 525,
#  b'emperor': 526,
#  b'young': 527,
#  b'anti': 528,
#  b'final': 529,
#  b'text': 530,
#  b'players': 531,
#  b'uk': 532,
#  b'april': 533,
#  b'run': 534,
#  b'september': 535,
#  b'addition': 536,
#  b'radio': 537,
#  b'live': 538,
#  b'august': 539,
#  b'taken': 540,
#  b'note': 541,
#  b'italian': 542,
#  b'lost': 543,
#  b'nature': 544,
#  b'project': 545,
#  b'technology': 546,
#  b'spanish': 547,
#  b'october': 548,
#  b'recent': 549,
#  b'rate': 550,
#  b'won': 551,
#  b'true': 552,
#  b'value': 553,
#  b'uses': 554,
#  b'russian': 555,
#  b'est': 556,
#  b'wrote': 557,
#  b'effect': 558,
#  b'album': 559,
#  b'southern': 560,
#  b'africa': 561,
#  b'whose': 562,
#  b'top': 563,
#  b'historical': 564,
#  b'australia': 565,
#  b'catholic': 566,
#  b'particularly': 567,
#  b'self': 568,
#  b'structure': 569,
#  b'record': 570,
#  b'evidence': 571,
#  b'rule': 572,
#  b'themselves': 573,
#  b'influence': 574,
#  b'cases': 575,
#  b'subject': 576,
#  b'referred': 577,
#  b'continued': 578,
#  b'nations': 579,
#  b'below': 580,
#  b'rock': 581,
#  b'japan': 582,
#  b'com': 583,
#  b'song': 584,
#  b'throughout': 585,
#  b'names': 586,
#  b'female': 587,
#  b'title': 588,
#  b'therefore': 589,
#  b'our': 590,
#  b'office': 591,
#  b'star': 592,
#  b'paul': 593,
#  b'too': 594,
#  b'cities': 595,
#  b'february': 596,
#  b'independent': 597,
#  b'author': 598,
#  b'problem': 599,
#  b'species': 600,
#  b'education': 601,
#  b'done': 602,
#  b'philosophy': 603,
#  b'come': 604,
#  b'higher': 605,
#  b'originally': 606,
#  b'market': 607,
#  b'town': 608,
#  b'my': 609,
#  b'season': 610,
#  b'love': 611,
#  b'strong': 612,
#  b'israel': 613,
#  b'irish': 614,
#  b'writer': 615,
#  b'films': 616,
#  b'elements': 617,
#  b'robert': 618,
#  b'whether': 619,
#  b'despite': 620,
#  b'eventually': 621,
#  b'here': 622,
#  b'football': 623,
#  b'action': 624,
#  b'internet': 625,
#  b'individual': 626,
#  b'sound': 627,
#  b'network': 628,
#  b'described': 629,
#  b'practice': 630,
#  b'characters': 631,
#  b're': 632,
#  b'royal': 633,
#  b'la': 634,
#  b'events': 635,
#  b'formed': 636,
#  b'commonly': 637,
#  b'base': 638,
#  b'received': 639,
#  b'african': 640,
#  b'problems': 641,
#  b'food': 642,
#  b'jews': 643,
#  b'able': 644,
#  b'male': 645,
#  b'typically': 646,
#  b'mass': 647,
#  b'complex': 648,
#  b'lower': 649,
#  b'includes': 650,
#  b'outside': 651,
#  b'legal': 652,
#  b'complete': 653,
#  b'significant': 654,
#  b'parliament': 655,
#  b'actually': 656,
#  b'business': 657,
#  b'fiction': 658,
#  b'physical': 659,
#  b'followed': 660,
#  b'deaths': 661,
#  b'key': 662,
#  b'leader': 663,
#  b'widely': 664,
#  b'page': 665,
#  b'basic': 666,
#  b'types': 667,
#  b'henry': 668,
#  b'elected': 669,
#  b'beginning': 670,
#  b'fire': 671,
#  b'building': 672,
#  b'independence': 673,
#  b'went': 674,
#  b'movie': 675,
#  b'aircraft': 676,
#  b'ever': 677,
#  b'canadian': 678,
#  b'material': 679,
#  b'births': 680,
#  b'video': 681,
#  b'news': 682,
#  b'future': 683,
#  b'scientific': 684,
#  b'simply': 685,
#  b'go': 686,
#  b'defined': 687,
#  b'laws': 688,
#  b'get': 689,
#  b'close': 690,
#  b'industry': 691,
#  b'specific': 692,
#  b'examples': 693,
#  b'believe': 694,
#  b'services': 695,
#  b'idea': 696,
#  b'method': 697,
#  b'introduced': 698,
#  b'points': 699,
#  b'return': 700,
#  b'cause': 701,
#  b'indian': 702,
#  b'britain': 703,
#  b'features': 704,
#  b'majority': 705,
#  b'size': 706,
#  b'post': 707,
#  b'lead': 708,
#  b'organization': 709,
#  b'cannot': 710,
#  b'designed': 711,
#  b'ireland': 712,
#  b'cross': 713,
#  b'classical': 714,
#  b'personal': 715,
#  b'writing': 716,
#  b'concept': 717,
#  b'associated': 718,
#  b'required': 719,
#  b'soon': 720,
#  b'changes': 721,
#  b'california': 722,
#  b'located': 723,
#  b'sense': 724,
#  b'believed': 725,
#  b'away': 726,
#  b'started': 727,
#  b'co': 728,
#  b'religion': 729,
#  b'mother': 730,
#  b'county': 731,
#  b'rules': 732,
#  b'studies': 733,
#  b'yet': 734,
#  b'find': 735,
#  b'knowledge': 736,
#  b'put': 737,
#  b'founded': 738,
#  b'policy': 739,
#  b'currently': 740,
#  b'provide': 741,
#  b'working': 742,
#  b'media': 743,
#  b'election': 744,
#  b'australian': 745,
#  b'me': 746,
#  b'thomas': 747,
#  b'allowed': 748,
#  b'russia': 749,
#  b'earlier': 750,
#  b'greater': 751,
#  b'limited': 752,
#  b'object': 753,
#  b'brought': 754,
#  b'online': 755,
#  b'association': 756,
#  b'lord': 757,
#  b'mostly': 758,
#  b'blue': 759,
#  b'constitution': 760,
#  b'across': 761,
#  b'added': 762,
#  b'interest': 763,
#  b'things': 764,
#  b'relations': 765,
#  b'speed': 766,
#  b'federal': 767,
#  b'singer': 768,
#  b'effects': 769,
#  b'growth': 770,
#  b'sources': 771,
#  b'your': 772,
#  b'remains': 773,
#  b'z': 774,
#  b'probably': 775,
#  b'gave': 776,
#  b'simple': 777,
#  b'attack': 778,
#  b'longer': 779,
#  b'reference': 780,
#  b'saint': 781,
#  b'success': 782,
#  b'killed': 783,
#  b'past': 784,
#  b'career': 785,
#  b'need': 786,
#  b'park': 787,
#  b'definition': 788,
#  b'say': 789,
#  b'etc': 790,
#  b'give': 791,
#  b'peace': 792,
#  b'chief': 793,
#  b'stories': 794,
#  b'security': 795,
#  b'wide': 796,
#  b'ball': 797,
#  b'saw': 798,
#  b'machine': 799,
#  b'better': 800,
#  b'cell': 801,
#  b'leading': 802,
#  b'becomes': 803,
#  b'spain': 804,
#  b'larger': 805,
#  b'products': 806,
#  b'parties': 807,
#  b'night': 808,
#  b'remained': 809,
#  b'prize': 810,
#  b'months': 811,
#  b'website': 812,
#  b'big': 813,
#  b'cultural': 814,
#  b'money': 815,
#  b'help': 816,
#  b'territory': 817,
#  b'private': 818,
#  b'moved': 819,
#  b'letter': 820,
#  b'wife': 821,
#  b'politics': 822,
#  b'lines': 823,
#  b'largely': 824,
#  b'contains': 825,
#  b'companies': 826,
#  b'lake': 827,
#  b'perhaps': 828,
#  b'green': 829,
#  b'already': 830,
#  b'dead': 831,
#  b'iii': 832,
#  b'library': 833,
#  b'separate': 834,
#  b'refer': 835,
#  b'makes': 836,
#  b'appeared': 837,
#  b'dutch': 838,
#  b'holy': 839,
#  b'era': 840,
#  b'novel': 841,
#  b'successful': 842,
#  b'italy': 843,
#  b'letters': 844,
#  b'results': 845,
#  b'matter': 846,
#  b'produce': 847,
#  b'origin': 848,
#  b'claim': 849,
#  b'whole': 850,
#  b'directly': 851,
#  b'attempt': 852,
#  b'actress': 853,
#  b'surface': 854,
#  b'revolution': 855,
#  b'highly': 856,
#  b'caused': 857,
#  b'status': 858,
#  b'musical': 859,
#  b'richard': 860,
#  b'commercial': 861,
#  b'division': 862,
#  b'color': 863,
#  b'health': 864,
#  b'coast': 865,
#  b'release': 866,
#  b'latter': 867,
#  b'authority': 868,
#  b'treaty': 869,
#  b'turn': 870,
#  b'michael': 871,
#  b'nation': 872,
#  b'direct': 873,
#  b'asia': 874,
#  b'edition': 875,
#  b'programming': 876,
#  b'playing': 877,
#  b'date': 878,
#  b'mary': 879,
#  b'native': 880,
#  b'whom': 881,
#  b'married': 882,
#  b'towards': 883,
#  b'issues': 884,
#  b'double': 885,
#  b'primary': 886,
#  b'basis': 887,
#  b'allow': 888,
#  b'enough': 889,
#  b'memory': 890,
#  b'reason': 891,
#  b'web': 892,
#  b'exist': 893,
#  b'provided': 894,
#  b'oil': 895,
#  b'course': 896,
#  b'functions': 897,
#  b'alexander': 898,
#  b'analysis': 899,
#  b'chemical': 900,
#  b'mid': 901,
#  b'replaced': 902,
#  b'queen': 903,
#  b'claims': 904,
#  b'tv': 905,
#  b'sun': 906,
#  b'literature': 907,
#  b'metal': 908,
#  b'amount': 909,
#  b'divided': 910,
#  b'blood': 911,
#  b'likely': 912,
#  b'access': 913,
#  b'average': 914,
#  b'length': 915,
#  b'smaller': 916,
#  b'medical': 917,
#  b'property': 918,
#  b'students': 919,
#  b'degree': 920,
#  b'elections': 921,
#  b'club': 922,
#  b'claimed': 923,
#  b'performance': 924,
#  b'director': 925,
#  b'digital': 926,
#  b'front': 927,
#  b'museum': 928,
#  b'difficult': 929,
#  b'tradition': 930,
#  b'nearly': 931,
#  b'schools': 932,
#  b'washington': 933,
#  b'gas': 934,
#  b'jesus': 935,
#  b'map': 936,
#  b'louis': 937,
#  b'rome': 938,
#  b'unit': 939,
#  b'baseball': 940,
#  b'mind': 941,
#  b'peter': 942,
#  b'mark': 943,
#  b'collection': 944,
#  b'product': 945,
#  b'congress': 946,
#  b'programs': 947,
#  b'changed': 948,
#  b'ideas': 949,
#  b'moon': 950,
#  b'entire': 951,
#  b'user': 952,
#  b'ground': 953,
#  b'records': 954,
#  b'frequently': 955,
#  b'increase': 956,
#  b'highest': 957,
#  b'sent': 958,
#  b'finally': 959,
#  b'board': 960,
#  b'don': 961,
#  b'notable': 962,
#  b'read': 963,
#  b'methods': 964,
#  b'recently': 965,
#  b'bit': 966,
#  b'involved': 967,
#  b'variety': 968,
#  b'call': 969,
#  b'democratic': 970,
#  b'ten': 971,
#  b'served': 972,
#  b'minor': 973,
#  b'hard': 974,
#  b'birth': 975,
#  b'objects': 976,
#  b'nuclear': 977,
#  b'increased': 978,
#  b'section': 979,
#  b'street': 980,
#  b'windows': 981,
#  b'relatively': 982,
#  b'car': 983,
#  b'move': 984,
#  b'create': 985,
#  b'returned': 986,
#  b'bank': 987,
#  b'conditions': 988,
#  b'operation': 989,
#  b'adopted': 990,
#  b'relationship': 991,
#  b'christ': 992,
#  b'hall': 993,
#  b'appear': 994,
#  b'rest': 995,
#  b'child': 996,
#  b'element': 997,
#  b'appears': 998,
#  b'takes': 999,
#  ...}

# %% [markdown]
# ## 所有词转换成ID

# %%
data = list()
unk_count = 0
for word in text_words:
    # 全部转换成id
    index = word2id.get(word, 0)
    if index == 0:
        unk_count += 1
    data.append(index)

count[0] = ('UNK', unk_count)
# 还要做一个id2word，用来检验结果
id2word = dict(zip(word2id.values(), word2id.keys()))

print("Words count:", len(text_words))
print("Unique words:", len(set(text_words)))
print("Vocabulary size:", vocabulary_size)
print("Most common words:", count[:10])
# Out:
# Words count: 17005207
# Unique words: 253854
# Vocabulary size: 47135
# Most common words: [('UNK', 444176), (b'the', 1061396), (b'of', 593677), (b'and', 416629), (b'one', 411764), (b'in', 372201), (b'a', 325873), (b'to', 316376), (b'zero', 264975), (b'nine', 250430)]

# %% [markdown]
# ## 构建所需训练数据

# %%
data_index = 0
# 不断生成输入输出对
def next_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    # 输入
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    # 标签
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # 7为窗口大小，左3右3中间1
    span = 2 * skip_window + 1
    # 创建一个长度为7的队列
    buffer = collections.deque(maxlen=span)
    # 循环器，都取完了，再重头来一次。
    if data_index + span > len(data):
        data_index = 0
    # 队列里存的是当前窗口，例如deque([5234, 3081, 12, 6, 195, 2, 3134], maxlen=7)
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    # 遍历
    # num_skips表示取多少组不同的词作为输出，此例为2
    for i in range(batch_size // num_skips):
        # 上下文就是[0, 1, 2, 4, 5, 6]
        context_words = [w for w in range(span) if w != skip_window]
        # 在上下文里随机选2个候选词
        words_to_use = random.sample(context_words, num_skips)
        # 遍历每一个候选词，用其当做输出也就是标签
        for j, context_word in enumerate(words_to_use):
            # 输入都为当前窗口的中间词，即3
            batch[i * num_skips + j] = buffer[skip_window]
            # 用当前候选词当做标签
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer.extend(data[0:span])
            data_index = span
        else:
            # 之前已经传入7个词了，窗口要右移了，例如原来为[5234, 3081, 12, 6, 195, 2, 3134]，
            # 现在为[3081, 12, 6, 195, 2, 3134, 46]
            buffer.append(data[data_index])
            data_index += 1

    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %% [markdown]
# ## 定义参数

# %%
with tf.device('/cpu:0'):
    # 维度：47135, 200
    # embedding，初始向量
    embedding = tf.Variable(tf.random.normal([vocabulary_size, embedding_size]))
    # 负采样
    # 权重参数
    nce_weights = tf.Variable(tf.random.normal([vocabulary_size, embedding_size]))
    # 偏置项参数
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

# %% [markdown]
# ## 通过tf.nn.embedding_lookup函数将索引转换成词向量

# %%
def get_embedding(x):
    with tf.device('/cpu:0'):
        x_embed = tf.nn.embedding_lookup(embedding, x)
        return x_embed

# %% [markdown]
# ## 损失函数定义
# - 先分别计算出正样本和采样出的负样本对应的output和label
# - 再通过 sigmoid cross entropy来计算output和label的loss

# %%
def nce_loss(x_embed, y):
    with tf.device('/cpu:0'):
        y = tf.cast(y, tf.int64)
        loss = tf.reduce_mean(
            tf.nn.nce_loss(weights=nce_weights,
                           biases=nce_biases,
                           labels=y,
                           inputs=x_embed,
                           # 采样出多少个负样本
                           num_sampled=num_sampled,
                           num_classes=vocabulary_size))
        return loss

# %% [markdown]
# ## 评估模块

# %%
# Evaluation.
def evaluate(x_embed):
    with tf.device('/cpu:0'):
        # 单个词的向量
        x_embed = tf.cast(x_embed, tf.float32)
        # 归一化
        x_embed_norm = x_embed / tf.sqrt(tf.reduce_sum(tf.square(x_embed)))
        # 全部向量的
        embedding_norm = embedding / tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keepdims=True), tf.float32)
        # 计算余弦，判断相似度
        cosine_sim_op = tf.matmul(x_embed_norm, embedding_norm, transpose_b=True)
        return cosine_sim_op

# %% [markdown]
# ## 优化及执行优化

# %%
# 优化器
optimizer = tf.optimizers.SGD(learning_rate)
# 迭代优化
def run_optimization(x, y):
    with tf.device('/cpu:0'):
        with tf.GradientTape() as g:
            emb = get_embedding(x)
            loss = nce_loss(emb, y)

        # 计算梯度
        gradients = g.gradient(loss, [embedding, nce_weights, nce_biases])

        # 更新
        optimizer.apply_gradients(zip(gradients, [embedding, nce_weights, nce_biases]))

# %% [markdown]
# ## 训练模型

# %%
# 获取测试单词
x_test = np.array([word2id[w.encode('utf-8')] for w in eval_words])

# 计时开始
time1 = datetime.datetime.now()
# 训练
for step in range(1, num_steps + 1):
    batch_x, batch_y = next_batch(batch_size, num_skips, skip_window)
    run_optimization(batch_x, batch_y)
    # 打印结果
    if step % display_step == 0 or step == 1:
        loss = nce_loss(get_embedding(batch_x), batch_y)
        print("step: %i, loss: %f" % (step, loss))
        
    # Evaluation.
    if step % eval_step == 0 or step == 1:
        print("Evaluation...")
        sim = evaluate(get_embedding(x_test)).numpy()
        for i in range(len(eval_words)):
            # 返回前8个最相似的
            top_k = 8
            nearest = (-sim[i, :]).argsort()[1:top_k + 1]
            log_str = '"%s" nearest neighbors:' % eval_words[i]
            for k in range(top_k):
                log_str = '%s %s,' % (log_str, id2word[nearest[k]])
            print(log_str)
            
print(datetime.datetime.now() - time1)
# Out:
# step: 1, loss: 493.687012
# Evaluation...
# "nine" nearest neighbors: b'expiry', b'ethnic', b'domains', b'croatians', b'slaps', b'twh', b'handicraft', b'containers',
# "of" nearest neighbors: b'erupts', b'aging', b'turing', b'grammarian', b'compliant', b'cgpm', b'vitrification', b'values',
# "going" nearest neighbors: b'nunn', b'pros', b'sparing', b'copperfield', b'graphical', b'heist', b'wrongs', b'lak',
# "hardware" nearest neighbors: b'vinland', b'stitched', b'klingon', b'conspicuously', b'mcghee', b'procedure', b'starred', b'walden',
# "american" nearest neighbors: b'studios', b'rahul', b'switches', b'reinforces', b'splinter', b'spokesman', b'quatre', b'roundabout',
# "britain" nearest neighbors: b'obey', b'atalh', b'funimation', b'stipulation', b'betting', b'separators', b'pommel', b'sig',
# step: 10000, loss: 138.822708
# step: 20000, loss: 59.304836
# step: 30000, loss: 46.534019
# step: 40000, loss: 28.697681
# step: 50000, loss: 36.321007
# step: 60000, loss: 46.113037
# step: 70000, loss: 15.083533
# step: 80000, loss: 32.655289
# step: 90000, loss: 50.344666
# step: 100000, loss: 40.952888
# step: 110000, loss: 28.437468
# step: 120000, loss: 20.826912
# step: 130000, loss: 29.705185
# step: 140000, loss: 24.373592
# step: 150000, loss: 12.010213
# step: 160000, loss: 23.881227
# step: 170000, loss: 12.844652
# step: 180000, loss: 23.438538
# step: 190000, loss: 9.613237
# step: 200000, loss: 16.310371
# Evaluation...
# "nine" nearest neighbors: b'seven', b'four', b'five', b'three', b'six', b'eight', b'one', b'two',
# "of" nearest neighbors: b'the', b'on', b'from', b'a', b'with', b'in', b'for', b'by',
# "going" nearest neighbors: b'which', b'time', b'use', b'or', b'as', b'also', b'be', b'been',
# "hardware" nearest neighbors: b'made', b'since', b't', b'some', b'b', UNK, b'one', b'under',
# "american" nearest neighbors: UNK, b'and', b's', b'from', b'in', b'about', b'on', b'after',
# "britain" nearest neighbors: b'or', b'may', b'than', b'used', b'have', b'would', b'them', b'been',
# step: 210000, loss: 12.281222
# step: 220000, loss: 14.801325
# step: 230000, loss: 14.485844
# step: 240000, loss: 6.765178
# step: 250000, loss: 7.130709
# step: 260000, loss: 10.548311
# step: 270000, loss: 12.129307
# step: 280000, loss: 6.177320
# step: 290000, loss: 7.573402
# step: 300000, loss: 10.825046
# step: 310000, loss: 11.652145
# step: 320000, loss: 11.851534
# step: 330000, loss: 7.477214
# step: 340000, loss: 8.766274
# step: 350000, loss: 15.086726
# step: 360000, loss: 8.264629
# step: 370000, loss: 7.987485
# step: 380000, loss: 7.981206
# step: 390000, loss: 9.597991
# step: 400000, loss: 10.317738
# Evaluation...
# "nine" nearest neighbors: b'seven', b'eight', b'six', b'four', b'one', b'five', b'three', b'two',
# "of" nearest neighbors: b'and', b'a', b'the', b'by', b'is', b'or', b'while', b'with',
# "going" nearest neighbors: b'use', b'an', b'example', b'such', b'life', b'form', b'is', b'was',
# "hardware" nearest neighbors: b't', b'university', b'however', b'or', b'system', b'while', b'these', b'list',
# "american" nearest neighbors: b'from', b'english', b'in', b'since', b's', UNK, b'british', b'including',
# "britain" nearest neighbors: b'than', b'may', b'others', b't', b'are', b'were', b'or', b'use',
# step: 410000, loss: 7.274259
# step: 420000, loss: 13.095809
# step: 430000, loss: 9.651428
# step: 440000, loss: 7.617493
# step: 450000, loss: 6.415250
# step: 460000, loss: 8.096091
# step: 470000, loss: 4.887653
# step: 480000, loss: 16.937454
# step: 490000, loss: 6.229112
# step: 500000, loss: 11.073376
# step: 510000, loss: 10.320219
# step: 520000, loss: 8.118151
# step: 530000, loss: 8.096376
# step: 540000, loss: 7.495970
# step: 550000, loss: 10.606848
# step: 560000, loss: 7.479241
# step: 570000, loss: 6.419781
# step: 580000, loss: 7.110516
# step: 590000, loss: 6.956989
# step: 600000, loss: 6.230039
# Evaluation...
# "nine" nearest neighbors: b'eight', b'seven', b'six', b'one', b'four', b'five', b'three', b'two',
# "of" nearest neighbors: b'the', b'and', b'including', b'a', b'an', b'in', b'became', b'its',
# "going" nearest neighbors: b'power', b'use', b'so', b'time', b'both', b'even', b'them', b'that',
# "hardware" nearest neighbors: b't', b'list', b'book', b'as', b'of', b'i', b'also', b'which',
# "american" nearest neighbors: b'english', b'french', b'german', b's', b'british', b'on', b'from', b'in',
# "britain" nearest neighbors: b'than', b'others', b'may', b'and', b'has', b'all', b'only', b'were',
# step: 610000, loss: 4.752120
# step: 620000, loss: 6.374070
# step: 630000, loss: 6.088048
# step: 640000, loss: 9.544558
# step: 650000, loss: 8.302259
# step: 660000, loss: 6.309435
# step: 670000, loss: 6.006846
# step: 680000, loss: 4.924155
# step: 690000, loss: 6.669247
# step: 700000, loss: 6.911783
# step: 710000, loss: 12.996111
# step: 720000, loss: 5.933291
# step: 730000, loss: 7.848700
# step: 740000, loss: 6.565542
# step: 750000, loss: 13.068319
# step: 760000, loss: 6.913547
# step: 770000, loss: 11.443413
# step: 780000, loss: 7.337367
# step: 790000, loss: 9.675024
# step: 800000, loss: 5.564295
# Evaluation...
# "nine" nearest neighbors: b'eight', b'seven', b'six', b'four', b'five', b'one', b'three', b'two',
# "of" nearest neighbors: b'and', b'the', b'for', b'including', b'with', b'a', b'in', b'from',
# "going" nearest neighbors: b'set', b'power', b'order', b'its', b'even', b'any', b'all', b'such',
# "hardware" nearest neighbors: b'word', b't', b'as', UNK, b'film', b'include', b'through', b'with',
# "american" nearest neighbors: b'english', b'british', b'born', b'b', b'german', b'd', b'french', b'john',
# "britain" nearest neighbors: b'large', b'were', b'others', b'major', b'modern', b'may', b'are', b'number',
